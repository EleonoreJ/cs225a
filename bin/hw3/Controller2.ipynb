# %% [markdown]
# # 2.d Joints limits

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

with open('../../hw3/controller2.txt') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    t_posx = []
    t_posy = []
    t_posz = []
    t4 = []
    t6 = []
    xdx = []
    xdy = []
    xdz = []
    t4_up = []
    t4_low = []
    t6_up = []
    t6_low = []
    for row in readCSV:
        t_posx.append(float(row[0]))
        t_posy.append(float(row[1]))
        t_posz.append(float(row[2]))
        xdx.append(float(row[3]))
        xdy.append(float(row[4]))
        xdz.append(float(row[5]))
        t4.append(float(row[6]))
        t6.append(float(row[7]))
        t4_up.append(float(row[8]))
        t4_low.append(float(row[9]))
        t6_low.append(float(row[10]))
        t6_up.append(float(row[11]))
plt.plot(t_posx, label="x")
plt.plot(t_posy, label="y")
plt.plot(t_posz, label="z")
plt.plot(xdx, label="x desired")
plt.plot(xdy, label="y desired")
plt.plot(xdz, label="z desired")
plt.title("End effector trajectories")
plt.xlabel("iterations")
plt.ylabel("Positions (m)")
plt.legend()
plt.show()
plt.plot(t4, label = "Joint 4")
plt.plot(t4_low, "r", label = "4 lower limit")
plt.plot(t4_up, "r", label = "4 upper limit")
plt.title("Joints trajectory")
plt.xlabel("iterations")
plt.ylabel("Joint angles (rad)")
plt.legend()
plt.show()
plt.plot(t6, label = "Joint 6")
plt.plot(t6_low, "g", label = "6 lower limit")
plt.plot(t6_up, "g", label = "6 upper limit")
plt.title("Joints trajectory")
plt.xlabel("iterations")
plt.ylabel("Joint angles (rad)")
plt.legend()
plt.show()

# %%
print("minimum angle Joint 4:" + str(180*min(t4)/np.pi))
print("extrema angles Joint 6:" + str(180*min(t6)/np.pi) + "," + str(180*max(t6)/np.pi))
# Out:
# minimum angle Joint 4:-190.73535816787054
# extrema angles Joint 6:42.03373083684405,79.99980510293634

# %% [markdown]
# The system is able to track the desired positions, but Joint 4 reaches its limit which is -170. The minimum angle is -190. Joint 6 does not seem to reach its limits (0, 210).

# %% [markdown]
# # 2.e Avoid joint limits in the nullspace of the task

# %%
with open('../../hw3/controller2.txt') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    t_posx = []
    t_posy = []
    t_posz = []
    t4 = []
    t6 = []
    xdx = []
    xdy = []
    xdz = []
    t4_up = []
    t4_low = []
    t6_up = []
    t6_low = []
    for row in readCSV:
        t_posx.append(float(row[0]))
        t_posy.append(float(row[1]))
        t_posz.append(float(row[2]))
        xdx.append(float(row[3]))
        xdy.append(float(row[4]))
        xdz.append(float(row[5]))
        t4.append(float(row[6]))
        t6.append(float(row[7]))
        t4_up.append(float(row[8]))
        t4_low.append(float(row[9]))
        t6_low.append(float(row[10]))
        t6_up.append(float(row[11]))
plt.plot(t_posx, label="x")
plt.plot(t_posy, label="y")
plt.plot(t_posz, label="z")
plt.plot(xdx, label="x desired")
plt.plot(xdy, label="y desired")
plt.plot(xdz, label="z desired")
plt.title("End effector trajectories")
plt.xlabel("iterations")
plt.ylabel("Positions (m)")
plt.legend()
plt.show()
plt.plot(t4, label = "Joint 4")
plt.plot(t4_low, "r", label = "4 lower limit")
plt.plot(t4_up, "r", label = "4 upper limit")
plt.title("Joints trajectory")
plt.xlabel("iterations")
plt.ylabel("Joint angles (rad)")
plt.legend()
plt.show()
plt.plot(t6, label = "Joint 6")
plt.plot(t6_low, "g", label = "6 lower limit")
plt.plot(t6_up, "g", label = "6 upper limit")
plt.title("Joints trajectory")
plt.xlabel("iterations")
plt.ylabel("Joint angles (rad)")
plt.legend()
plt.show()

# %% [markdown]
# When adding the potential field to avoid joint limits, we are still able to track the desired end-effector position. We can observe in the joint trajectories that the final position of Joint 4 is far from its limit compare to the previous question. However, during the task Joint 4 is still close to its limits.

# %% [markdown]
# # 2.f Desired position change

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

with open('../../hw3/controller2.txt') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    t_posx = []
    t_posy = []
    t_posz = []
    t4 = []
    t6 = []
    xdx = []
    xdy = []
    xdz = []
    t4_up = []
    t4_low = []
    t6_up = []
    t6_low = []
    for row in readCSV:
        t_posx.append(float(row[0]))
        t_posy.append(float(row[1]))
        t_posz.append(float(row[2]))
        xdx.append(float(row[3]))
        xdy.append(float(row[4]))
        xdz.append(float(row[5]))
        t4.append(float(row[6]))
        t6.append(float(row[7]))
        t4_up.append(float(row[8]))
        t4_low.append(float(row[9]))
        t6_low.append(float(row[10]))
        t6_up.append(float(row[11]))
plt.plot(t_posx, label="x")
plt.plot(t_posy, label="y")
plt.plot(t_posz, label="z")
plt.plot(xdx, label="x desired")
plt.plot(xdy, label="y desired")
plt.plot(xdz, label="z desired")
plt.title("End effector trajectories")
plt.xlabel("iterations")
plt.ylabel("Positions (m)")
plt.legend()
plt.show()
plt.plot(t4, label = "Joint 4")
plt.plot(t4_low, "g", label = "4 lower limit")
plt.plot(t4_up, "g", label = "4 upper limit")
plt.title("Joints trajectory")
plt.xlabel("iterations")
plt.ylabel("Joint angles (rad)")
plt.legend()
plt.show()
plt.plot(t6, label = "Joint 6")
plt.plot(t6_low, "g", label = "6 lower limit")
plt.plot(t6_up, "g", label = "6 upper limit")
plt.title("Joints trajectory")
plt.xlabel("iterations")
plt.ylabel("Joint angles (rad)")
plt.legend()
plt.show()

# %% [markdown]
# In this question, we changed the desired end-effector position. Firstly, we see that we still reach the desired position and the joints final positions are far from their limits. Secondly, we observe that contrary to 2.e, Joint 4 does not approach its joint limits. This time, the limits are approached by Joint 6 ven if it is not reached.

# %% [markdown]
# # 2.g Torques not projected into the nullspace

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

with open('../../hw3/controller2.txt') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    t_posx = []
    t_posy = []
    t_posz = []
    t4 = []
    t6 = []
    xdx = []
    xdy = []
    xdz = []
    t4_up = []
    t4_low = []
    t6_up = []
    t6_low = []
    for row in readCSV:
        t_posx.append(float(row[0]))
        t_posy.append(float(row[1]))
        t_posz.append(float(row[2]))
        xdx.append(float(row[3]))
        xdy.append(float(row[4]))
        xdz.append(float(row[5]))
        t4.append(float(row[6]))
        t6.append(float(row[7]))
        t4_up.append(float(row[8]))
        t4_low.append(float(row[9]))
        t6_low.append(float(row[10]))
        t6_up.append(float(row[11]))
plt.plot(t_posx, label="x")
plt.plot(t_posy, label="y")
plt.plot(t_posz, label="z")
plt.plot(xdx, label="x desired")
plt.plot(xdy, label="y desired")
plt.plot(xdz, label="z desired")
plt.title("End effector trajectories")
plt.xlabel("iterations")
plt.ylabel("Positions (m)")
plt.legend()
plt.show()
plt.plot(t4, label = "Joint 4")
plt.plot(t4_low, "g", label = "4 lower limit")
plt.plot(t4_up, "g", label = "4 upper limit")
plt.title("Joints trajectory")
plt.xlabel("iterations")
plt.ylabel("Joint angles (rad)")
plt.legend()
plt.show()
plt.plot(t6, label = "Joint 6")
plt.plot(t6_low, "g", label = "6 lower limit")
plt.plot(t6_up, "g", label = "6 upper limit")
plt.title("Joints trajectory")
plt.xlabel("iterations")
plt.ylabel("Joint angles (rad)")
plt.legend()
plt.show()

# %% [markdown]
# In this case, joints do not approach their limits. However, the end-effector does not reach the desired position. This is due to the torques induced by the potential field. As they are not porjected onto the nullspace, they disturb the task completion.
# Controller from 2.e and 2.f is preferable because the robot reaches the desired position and avoid as possible joints limits. Indeed, the top priority is to reach the desired position.

# %% [markdown]
# h) trajectory tracking xdot, xddot
